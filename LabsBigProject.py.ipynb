# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import math
from statistics import mode

client_id = "2414011f2fab4d93ab24db4093524758"
client_secret = "b4b85483ecac42cfa2d9e8b255137757"

sp = spotipy.Spotify(auth_manager = SpotifyClientCredentials(client_id, client_secret))

sp.trace=False
playlist = sp.user_playlist("2020 - IMPALA Album of the Year Award - Albums", "3lyIN15h9uVlkvPKahuOfX")
# playlist = sp.user_playlist("Reassuring", "52KwifcwbsyxMfXUhcpMO4") # ID playlisty to ten fragment linku po ukośniku i przed znakiem zapytania
songs = playlist["tracks"]["items"]
ids = []
for i in range(len(songs)):
    ids.append(songs[i]["track"]["id"])   #tutaj jak zmienimy id na name to dostajemy tytuły piosenek
features = sp.audio_features(ids)
odległości = []
target_id = "3cyHz6vzksSQ92KEkr0wu3"
target = sp.audio_features(target_id) 
df = pd.DataFrame(features)

# cechy = {"taneczność": "danceability"}
# for i in range(len(songs)):
#     odległość = math.sqrt((float(target[0][cechy["taneczność"]])-float(features[i][cechy["taneczność"]]))**2+(float(target[0]["energy"])-float(features[i]["energy"]))**2
#                 +(float(target[0]["key"])-float(features[i]["key"]))**2+(float(target[0]["acousticness"])-float(features[i]["acousticness"]))**2)
#     odległości.append([round(odległość,2), features[i]["id"]])
# odległości.sort()
# print("Posortowane odległości:", odległości)
# obiekty = []
# k = int(input("Wybierz liczbę sąsiadów\n")) 
# for i in range(k):
#     obiekty.append(odległości[i][1])
# print("Oto proponowane piosenki:", obiekty)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.7360  0.4180    2    -7.703     1       0.0272       0.00536
# 1         0.5580  0.6320    4    -6.688     1       0.0469       0.11600
# 2         0.5540  0.6120    2    -5.893     1       0.0295       0.00089
# 3         0.5370  0.5720    2    -7.979     1       0.0275       0.01490
# 4         0.6040  0.3390    2    -9.133     1       0.0327       0.35500
# ..           ...     ...  ...       ...   ...          ...           ...
# 95        0.1900  0.0946    0   -15.139     0       0.0324       0.96100
# 96        0.2210  0.1180    4   -14.747     0       0.0449       0.95100
# 97        0.2040  0.0827    0   -18.021     0       0.0430       0.92700
# 98        0.0864  0.0662    9   -14.721     1       0.0420       0.88600
# 99        0.2840  0.5790    5    -6.692     1       0.0370       0.56500
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.2290   0.4850   95.020  audio_features
# 1           0.000000    0.1910   0.7710  169.808  audio_features
# 2           0.000195    0.3270   0.3000  105.063  audio_features
# 3           0.002630    0.2690   0.1970  109.961  audio_features
# 4           0.000000    0.0992   0.2640  130.036  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.866000    0.1060   0.0363   76.471  audio_features
# 96          0.801000    0.1140   0.0374   81.740  audio_features
# 97          0.894000    0.1050   0.0349  111.020  audio_features
# 98          0.919000    0.0852   0.0369   70.173  audio_features
# 99          0.673000    0.3440   0.1070   94.892  audio_features
#
#                         id                                   uri  \
# 0   5wU9xXPdfTXqN8rBrTHIW3  spotify:track:5wU9xXPdfTXqN8rBrTHIW3
# 1   5qN4IepkesMy83eDzOvHOE  spotify:track:5qN4IepkesMy83eDzOvHOE
# 2   7cym1cTM856K6vNgfyN7iP  spotify:track:7cym1cTM856K6vNgfyN7iP
# 3   5RNTax0NA38ot5tcdz4DbL  spotify:track:5RNTax0NA38ot5tcdz4DbL
# 4   7Djp7Vkm765LIqLODQXEi7  spotify:track:7Djp7Vkm765LIqLODQXEi7
# ..                     ...                                   ...
# 95  6at2OT6ik9751T772Sn53B  spotify:track:6at2OT6ik9751T772Sn53B
# 96  381qo0VUzFJWO6PTRf3rsA  spotify:track:381qo0VUzFJWO6PTRf3rsA
# 97  3XTIMboeTUHNRIZpfOd6Js  spotify:track:3XTIMboeTUHNRIZpfOd6Js
# 98  3ZVLbEbxrLbxTqXG3pcTnh  spotify:track:3ZVLbEbxrLbxTqXG3pcTnh
# 99  4lIOFagrZ6UlIjEM0ZP6q8  spotify:track:4lIOFagrZ6UlIjEM0ZP6q8
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/5wU9xXPdfTXq...
# 1   https://api.spotify.com/v1/tracks/5qN4IepkesMy...
# 2   https://api.spotify.com/v1/tracks/7cym1cTM856K...
# 3   https://api.spotify.com/v1/tracks/5RNTax0NA38o...
# 4   https://api.spotify.com/v1/tracks/7Djp7Vkm765L...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/6at2OT6ik975...
# 96  https://api.spotify.com/v1/tracks/381qo0VUzFJW...
# 97  https://api.spotify.com/v1/tracks/3XTIMboeTUHN...
# 98  https://api.spotify.com/v1/tracks/3ZVLbEbxrLbx...
# 99  https://api.spotify.com/v1/tracks/4lIOFagrZ6Ul...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/5wU9...       184634
# 1   https://api.spotify.com/v1/audio-analysis/5qN4...       161100
# 2   https://api.spotify.com/v1/audio-analysis/7cym...       181025
# 3   https://api.spotify.com/v1/audio-analysis/5RNT...       260888
# 4   https://api.spotify.com/v1/audio-analysis/7Djp...       260001
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/6at2...       254974
# 96  https://api.spotify.com/v1/audio-analysis/381q...       194008
# 97  https://api.spotify.com/v1/audio-analysis/3XTI...       459455
# 98  https://api.spotify.com/v1/audio-analysis/3ZVL...       314862
# 99  https://api.spotify.com/v1/audio-analysis/4lIO...       290279
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                3
# ..             ...
# 95               3
# 96               1
# 97               4
# 98               3
# 99               3
#
# [100 rows x 18 columns]
