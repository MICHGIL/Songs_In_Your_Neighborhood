# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import math
from statistics import mode

client_id = "2414011f2fab4d93ab24db4093524758"
client_secret = "b4b85483ecac42cfa2d9e8b255137757"

sp = spotipy.Spotify(auth_manager = SpotifyClientCredentials(client_id, client_secret))

sp.trace=False
# playlist = sp.user_playlist("2020 - IMPALA Album of the Year Award - Albums", "3lyIN15h9uVlkvPKahuOfX")
playlist = sp.user_playlist("Reassuring", "52KwifcwbsyxMfXUhcpMO4") # ID playlisty to ten fragment linku po ukośniku i przed znakiem zapytania
songs = playlist["tracks"]["items"]
ids = []
for i in range(len(songs)):
    ids.append(songs[i]["track"]["id"])   #tutaj jak zmienimy id na name to dostajemy tytuły piosenek
features = sp.audio_features(ids)
odległości = []
target_id = "3cyHz6vzksSQ92KEkr0wu3"
target = sp.audio_features(target_id) 
df = pd.DataFrame(features)
for i in range(4):
    df.index[df["id"] == "7cym1cTM856K6vNgfyN7iP"]
df
# cechy = {"taneczność": "danceability"}
# for i in range(len(songs)):
#     odległość = math.sqrt((float(target[0][cechy["taneczność"]])-float(features[i][cechy["taneczność"]]))**2+(float(target[0]["energy"])-float(features[i]["energy"]))**2
#                 +(float(target[0]["key"])-float(features[i]["key"]))**2+(float(target[0]["acousticness"])-float(features[i]["acousticness"]))**2)
#     odległości.append([round(odległość,2), features[i]["id"]])
# odległości.sort()
# print("Posortowane odległości:", odległości)
# obiekty = []
# k = int(input("Wybierz liczbę sąsiadów\n")) 
# for i in range(k):
#     obiekty.append(odległości[i][1])
# print("Oto proponowane piosenki:", obiekty)

# '4OtGu9O6vHOOsDECNqBMw3', '5DCaAsjQRLYvvdFUzaYnAz', '7BeHlZdkTMscYLJuMLUVUH']
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.684   0.452    5    -7.126     1       0.2620       0.06290
# 1          0.613   0.668    0    -6.134     1       0.1620       0.00421
# 2          0.719   0.490    8    -7.449     1       0.0782       0.35200
# 3          0.736   0.603    1    -7.582     1       0.0576       0.24600
# 4          0.319   0.739    0    -5.740     1       0.2720       0.02850
# 5          0.544   0.759   10    -4.839     1       0.1210       0.25700
# 6          0.766   0.522    6    -6.860     1       0.1480       0.06500
# 7          0.806   0.608    1    -7.008     1       0.0659       0.01130
# 8          0.474   0.553    2    -5.592     1       0.2280       0.26500
# 9          0.708   0.494    5    -7.496     0       0.0365       0.69700
# 10         0.622   0.712    5    -7.321     1       0.0660       0.05730
# 11         0.618   0.596   11    -6.663     0       0.0805       0.55800
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.3020    0.752  177.851  audio_features
# 1           0.000002    0.3240    0.622  150.171  audio_features
# 2           0.000000    0.0871    0.681  105.192  audio_features
# 3           0.000053    0.1090    0.571  136.975  audio_features
# 4           0.000000    0.1110    0.449  194.169  audio_features
# 5           0.000065    0.3500    0.303  150.032  audio_features
# 6           0.003980    0.1010    0.525  156.077  audio_features
# 7           0.000000    0.6350    0.849   95.049  audio_features
# 8           0.000000    0.1610    0.323  203.001  audio_features
# 9           0.000115    0.3400    0.760  142.921  audio_features
# 10          0.000000    0.1300    0.487  140.025  audio_features
# 11          0.000000    0.1500    0.325  100.028  audio_features
#
#                         id                                   uri  \
# 0   3JH1alhYiP4TTEsmDiNVrf  spotify:track:3JH1alhYiP4TTEsmDiNVrf
# 1   7eXT7U3FKrOM88xr1DsNwc  spotify:track:7eXT7U3FKrOM88xr1DsNwc
# 2   4OtGu9O6vHOOsDECNqBMw3  spotify:track:4OtGu9O6vHOOsDECNqBMw3
# 3   3bYcImhElMVe8rVPZQlcvg  spotify:track:3bYcImhElMVe8rVPZQlcvg
# 4   42ydLwx4i5V49RXHOozJZq  spotify:track:42ydLwx4i5V49RXHOozJZq
# 5   5DCaAsjQRLYvvdFUzaYnAz  spotify:track:5DCaAsjQRLYvvdFUzaYnAz
# 6   7BeHlZdkTMscYLJuMLUVUH  spotify:track:7BeHlZdkTMscYLJuMLUVUH
# 7   1huvTbEYtgltjQRXzrNKGi  spotify:track:1huvTbEYtgltjQRXzrNKGi
# 8   2LwodLGnuRGcqZA14BgeMZ  spotify:track:2LwodLGnuRGcqZA14BgeMZ
# 9   57zRWXTQCFRV3zwg0NR8Ck  spotify:track:57zRWXTQCFRV3zwg0NR8Ck
# 10  2QZ7WLBE8h2y1Y5Fb8RYbH  spotify:track:2QZ7WLBE8h2y1Y5Fb8RYbH
# 11  5cWIKVqSpJQiRmG59sfii5  spotify:track:5cWIKVqSpJQiRmG59sfii5
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/3JH1alhYiP4T...
# 1   https://api.spotify.com/v1/tracks/7eXT7U3FKrOM...
# 2   https://api.spotify.com/v1/tracks/4OtGu9O6vHOO...
# 3   https://api.spotify.com/v1/tracks/3bYcImhElMVe...
# 4   https://api.spotify.com/v1/tracks/42ydLwx4i5V4...
# 5   https://api.spotify.com/v1/tracks/5DCaAsjQRLYv...
# 6   https://api.spotify.com/v1/tracks/7BeHlZdkTMsc...
# 7   https://api.spotify.com/v1/tracks/1huvTbEYtglt...
# 8   https://api.spotify.com/v1/tracks/2LwodLGnuRGc...
# 9   https://api.spotify.com/v1/tracks/57zRWXTQCFRV...
# 10  https://api.spotify.com/v1/tracks/2QZ7WLBE8h2y...
# 11  https://api.spotify.com/v1/tracks/5cWIKVqSpJQi...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/3JH1...       158147
# 1   https://api.spotify.com/v1/audio-analysis/7eXT...       199747
# 2   https://api.spotify.com/v1/audio-analysis/4OtG...       168402
# 3   https://api.spotify.com/v1/audio-analysis/3bYc...       196452
# 4   https://api.spotify.com/v1/audio-analysis/42yd...       230227
# 5   https://api.spotify.com/v1/audio-analysis/5DCa...       184320
# 6   https://api.spotify.com/v1/audio-analysis/7BeH...       176040
# 7   https://api.spotify.com/v1/audio-analysis/1huv...       219840
# 8   https://api.spotify.com/v1/audio-analysis/2Lwo...       161880
# 9   https://api.spotify.com/v1/audio-analysis/57zR...       163172
# 10  https://api.spotify.com/v1/audio-analysis/2QZ7...       211360
# 11  https://api.spotify.com/v1/audio-analysis/5cWI...       190827
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# 8                4
# 9                4
# 10               4
# 11               4
