# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import math
from statistics import mode

client_id = "2414011f2fab4d93ab24db4093524758"
client_secret = "b4b85483ecac42cfa2d9e8b255137757"

sp = spotipy.Spotify(auth_manager = SpotifyClientCredentials(client_id, client_secret))

sp.trace=False
playlist = sp.user_playlist("2020 - IMPALA Album of the Year Award - Albums", "3lyIN15h9uVlkvPKahuOfX")
# playlist = sp.user_playlist("Reassuring", "52KwifcwbsyxMfXUhcpMO4") # ID playlisty to ten fragment linku po ukośniku i przed znakiem zapytania
songs = playlist["tracks"]["items"]
ids = []
for i in range(len(songs)):
    ids.append(songs[i]["track"]["id"])   #tutaj jak zmienimy id na name to dostajemy tytuły piosenek
features = sp.audio_features(ids)
odległości = []
target_id = "3cyHz6vzksSQ92KEkr0wu3"
target = sp.audio_features(target_id) 
features
# cechy = {"taneczność": "danceability"}
# for i in range(len(songs)):
#     odległość = math.sqrt((float(target[0][cechy["taneczność"]])-float(features[i][cechy["taneczność"]]))**2+(float(target[0]["energy"])-float(features[i]["energy"]))**2
#                 +(float(target[0]["key"])-float(features[i]["key"]))**2+(float(target[0]["acousticness"])-float(features[i]["acousticness"]))**2)
#     odległości.append([round(odległość,2), features[i]["id"]])
# odległości.sort()
# print("Posortowane odległości:", odległości)
# obiekty = []
# k = int(input("Wybierz liczbę sąsiadów\n")) 
# for i in range(k):
#     obiekty.append(odległości[i][1])
# print("Oto proponowane piosenki:", obiekty)
# Out:
# [{'danceability': 0.736,
#   'energy': 0.418,
#   'key': 2,
#   'loudness': -7.703,
#   'mode': 1,
#   'speechiness': 0.0272,
#   'acousticness': 0.00536,
#   'instrumentalness': 0,
#   'liveness': 0.229,
#   'valence': 0.485,
#   'tempo': 95.02,
#   'type': 'audio_features',
#   'id': '5wU9xXPdfTXqN8rBrTHIW3',
#   'uri': 'spotify:track:5wU9xXPdfTXqN8rBrTHIW3',
#   'track_href': 'https://api.spotify.com/v1/tracks/5wU9xXPdfTXqN8rBrTHIW3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5wU9xXPdfTXqN8rBrTHIW3',
#   'duration_ms': 184634,
#   'time_signature': 4},
#  {'danceability': 0.558,
#   'energy': 0.632,
#   'key': 4,
#   'loudness': -6.688,
#   'mode': 1,
#   'speechiness': 0.0469,
#   'acousticness': 0.116,
#   'instrumentalness': 0,
#   'liveness': 0.191,
#   'valence': 0.771,
#   'tempo': 169.808,
#   'type': 'audio_features',
#   'id': '5qN4IepkesMy83eDzOvHOE',
#   'uri': 'spotify:track:5qN4IepkesMy83eDzOvHOE',
#   'track_href': 'https://api.spotify.com/v1/tracks/5qN4IepkesMy83eDzOvHOE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5qN4IepkesMy83eDzOvHOE',
#   'duration_ms': 161100,
#   'time_signature': 4},
#  {'danceability': 0.554,
#   'energy': 0.612,
#   'key': 2,
#   'loudness': -5.893,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.00089,
#   'instrumentalness': 0.000195,
#   'liveness': 0.327,
#   'valence': 0.3,
#   'tempo': 105.063,
#   'type': 'audio_features',
#   'id': '7cym1cTM856K6vNgfyN7iP',
#   'uri': 'spotify:track:7cym1cTM856K6vNgfyN7iP',
#   'track_href': 'https://api.spotify.com/v1/tracks/7cym1cTM856K6vNgfyN7iP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7cym1cTM856K6vNgfyN7iP',
#   'duration_ms': 181025,
#   'time_signature': 4},
#  {'danceability': 0.537,
#   'energy': 0.572,
#   'key': 2,
#   'loudness': -7.979,
#   'mode': 1,
#   'speechiness': 0.0275,
#   'acousticness': 0.0149,
#   'instrumentalness': 0.00263,
#   'liveness': 0.269,
#   'valence': 0.197,
#   'tempo': 109.961,
#   'type': 'audio_features',
#   'id': '5RNTax0NA38ot5tcdz4DbL',
#   'uri': 'spotify:track:5RNTax0NA38ot5tcdz4DbL',
#   'track_href': 'https://api.spotify.com/v1/tracks/5RNTax0NA38ot5tcdz4DbL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5RNTax0NA38ot5tcdz4DbL',
#   'duration_ms': 260888,
#   'time_signature': 4},
#  {'danceability': 0.604,
#   'energy': 0.339,
#   'key': 2,
#   'loudness': -9.133,
#   'mode': 1,
#   'speechiness': 0.0327,
#   'acousticness': 0.355,
#   'instrumentalness': 0,
#   'liveness': 0.0992,
#   'valence': 0.264,
#   'tempo': 130.036,
#   'type': 'audio_features',
#   'id': '7Djp7Vkm765LIqLODQXEi7',
#   'uri': 'spotify:track:7Djp7Vkm765LIqLODQXEi7',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Djp7Vkm765LIqLODQXEi7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Djp7Vkm765LIqLODQXEi7',
#   'duration_ms': 260001,
#   'time_signature': 3},
#  {'danceability': 0.587,
#   'energy': 0.546,
#   'key': 6,
#   'loudness': -8.043,
#   'mode': 0,
#   'speechiness': 0.0382,
#   'acousticness': 0.0059,
#   'instrumentalness': 5.53e-06,
#   'liveness': 0.675,
#   'valence': 0.42,
#   'tempo': 120.02,
#   'type': 'audio_features',
#   'id': '38QKsrJJpTkK249jRarkBM',
#   'uri': 'spotify:track:38QKsrJJpTkK249jRarkBM',
#   'track_href': 'https://api.spotify.com/v1/tracks/38QKsrJJpTkK249jRarkBM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/38QKsrJJpTkK249jRarkBM',
#   'duration_ms': 257161,
#   'time_signature': 4},
#  {'danceability': 0.7,
#   'energy': 0.512,
#   'key': 2,
#   'loudness': -7.389,
#   'mode': 1,
#   'speechiness': 0.0368,
#   'acousticness': 0.003,
#   'instrumentalness': 1.98e-05,
#   'liveness': 0.47,
#   'valence': 0.208,
#   'tempo': 120.027,
#   'type': 'audio_features',
#   'id': '4dBRiJ7iqZO8dIrZJarQCa',
#   'uri': 'spotify:track:4dBRiJ7iqZO8dIrZJarQCa',
#   'track_href': 'https://api.spotify.com/v1/tracks/4dBRiJ7iqZO8dIrZJarQCa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4dBRiJ7iqZO8dIrZJarQCa',
#   'duration_ms': 241943,
#   'time_signature': 4},
#  {'danceability': 0.69,
#   'energy': 0.785,
#   'key': 9,
#   'loudness': -6.976,
#   'mode': 1,
#   'speechiness': 0.045,
#   'acousticness': 0.0287,
#   'instrumentalness': 3.44e-06,
#   'liveness': 0.115,
#   'valence': 0.518,
#   'tempo': 105.034,
#   'type': 'audio_features',
#   'id': '2iBJd0JYq1mOfJjY2Tds5Q',
#   'uri': 'spotify:track:2iBJd0JYq1mOfJjY2Tds5Q',
#   'track_href': 'https://api.spotify.com/v1/tracks/2iBJd0JYq1mOfJjY2Tds5Q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2iBJd0JYq1mOfJjY2Tds5Q',
#   'duration_ms': 177331,
#   'time_signature': 4},
#  {'danceability': 0.684,
#   'energy': 0.744,
#   'key': 9,
#   'loudness': -6.574,
#   'mode': 1,
#   'speechiness': 0.0482,
#   'acousticness': 0.0162,
#   'instrumentalness': 0,
#   'liveness': 0.337,
#   'valence': 0.786,
#   'tempo': 129.962,
#   'type': 'audio_features',
#   'id': '6hwR6mit2MMvcYPvX2OFZI',
#   'uri': 'spotify:track:6hwR6mit2MMvcYPvX2OFZI',
#   'track_href': 'https://api.spotify.com/v1/tracks/6hwR6mit2MMvcYPvX2OFZI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6hwR6mit2MMvcYPvX2OFZI',
#   'duration_ms': 163837,
#   'time_signature': 4},
#  {'danceability': 0.461,
#   'energy': 0.111,
#   'key': 9,
#   'loudness': -11.641,
#   'mode': 1,
#   'speechiness': 0.035,
#   'acousticness': 0.866,
#   'instrumentalness': 6.36e-05,
#   'liveness': 0.133,
#   'valence': 0.168,
#   'tempo': 106.07,
#   'type': 'audio_features',
#   'id': '6yLP8Gr90oQHzD0AwTn7r1',
#   'uri': 'spotify:track:6yLP8Gr90oQHzD0AwTn7r1',
#   'track_href': 'https://api.spotify.com/v1/tracks/6yLP8Gr90oQHzD0AwTn7r1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6yLP8Gr90oQHzD0AwTn7r1',
#   'duration_ms': 260584,
#   'time_signature': 3},
#  {'danceability': 0.763,
#   'energy': 0.345,
#   'key': 10,
#   'loudness': -12.445,
#   'mode': 1,
#   'speechiness': 0.0604,
#   'acousticness': 0.908,
#   'instrumentalness': 0,
#   'liveness': 0.0793,
#   'valence': 0.674,
#   'tempo': 146.066,
#   'type': 'audio_features',
#   'id': '2XUbkfMClkhYW3sbDuePoA',
#   'uri': 'spotify:track:2XUbkfMClkhYW3sbDuePoA',
#   'track_href': 'https://api.spotify.com/v1/tracks/2XUbkfMClkhYW3sbDuePoA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2XUbkfMClkhYW3sbDuePoA',
#   'duration_ms': 18600,
#   'time_signature': 4},
#  {'danceability': 0.448,
#   'energy': 0.569,
#   'key': 0,
#   'loudness': -6.708,
#   'mode': 0,
#   'speechiness': 0.0497,
#   'acousticness': 0.0233,
#   'instrumentalness': 0.000105,
#   'liveness': 0.196,
#   'valence': 0.0398,
#   'tempo': 73.118,
#   'type': 'audio_features',
#   'id': '3TWpxA3DRgBL0Z8MpuBfUx',
#   'uri': 'spotify:track:3TWpxA3DRgBL0Z8MpuBfUx',
#   'track_href': 'https://api.spotify.com/v1/tracks/3TWpxA3DRgBL0Z8MpuBfUx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3TWpxA3DRgBL0Z8MpuBfUx',
#   'duration_ms': 297987,
#   'time_signature': 4},
#  {'danceability': 0.671,
#   'energy': 0.601,
#   'key': 8,
#   'loudness': -7.685,
#   'mode': 0,
#   'speechiness': 0.0546,
#   'acousticness': 0.0485,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.368,
#   'tempo': 111.954,
#   'type': 'audio_features',
#   'id': '5qAFALeAlZi5dOKSJq4P5q',
#   'uri': 'spotify:track:5qAFALeAlZi5dOKSJq4P5q',
#   'track_href': 'https://api.spotify.com/v1/tracks/5qAFALeAlZi5dOKSJq4P5q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5qAFALeAlZi5dOKSJq4P5q',
#   'duration_ms': 201853,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.552,
#   'key': 1,
#   'loudness': -6.352,
#   'mode': 1,
#   'speechiness': 0.0407,
#   'acousticness': 0.00439,
#   'instrumentalness': 0.000158,
#   'liveness': 0.121,
#   'valence': 0.292,
#   'tempo': 119.992,
#   'type': 'audio_features',
#   'id': '2qsgWhDjjvEvmkdCgjO9ri',
#   'uri': 'spotify:track:2qsgWhDjjvEvmkdCgjO9ri',
#   'track_href': 'https://api.spotify.com/v1/tracks/2qsgWhDjjvEvmkdCgjO9ri',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2qsgWhDjjvEvmkdCgjO9ri',
#   'duration_ms': 203453,
#   'time_signature': 4},
#  {'danceability': 0.341,
#   'energy': 0.295,
#   'key': 9,
#   'loudness': -8.131,
#   'mode': 1,
#   'speechiness': 0.0311,
#   'acousticness': 0.913,
#   'instrumentalness': 0.000754,
#   'liveness': 0.271,
#   'valence': 0.0741,
#   'tempo': 132.35,
#   'type': 'audio_features',
#   'id': '4iFhtwMIjiIDWBckEWYxKQ',
#   'uri': 'spotify:track:4iFhtwMIjiIDWBckEWYxKQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4iFhtwMIjiIDWBckEWYxKQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4iFhtwMIjiIDWBckEWYxKQ',
#   'duration_ms': 235440,
#   'time_signature': 4},
#  {'danceability': 0.67,
#   'energy': 0.438,
#   'key': 4,
#   'loudness': -9.277,
#   'mode': 1,
#   'speechiness': 0.0334,
#   'acousticness': 0.6,
#   'instrumentalness': 0.00229,
#   'liveness': 0.166,
#   'valence': 0.0726,
#   'tempo': 109.981,
#   'type': 'audio_features',
#   'id': '0i2JnrPl173s6oLBSYZ8iD',
#   'uri': 'spotify:track:0i2JnrPl173s6oLBSYZ8iD',
#   'track_href': 'https://api.spotify.com/v1/tracks/0i2JnrPl173s6oLBSYZ8iD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0i2JnrPl173s6oLBSYZ8iD',
#   'duration_ms': 208640,
#   'time_signature': 4},
#  {'danceability': 0.519,
#   'energy': 0.707,
#   'key': 2,
#   'loudness': -4.685,
#   'mode': 0,
#   'speechiness': 0.0495,
#   'acousticness': 0.0813,
#   'instrumentalness': 0.000315,
#   'liveness': 0.146,
#   'valence': 0.265,
#   'tempo': 156.904,
#   'type': 'audio_features',
#   'id': '3yTDPOGviPZeO4j59elkXt',
#   'uri': 'spotify:track:3yTDPOGviPZeO4j59elkXt',
#   'track_href': 'https://api.spotify.com/v1/tracks/3yTDPOGviPZeO4j59elkXt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3yTDPOGviPZeO4j59elkXt',
#   'duration_ms': 208973,
#   'time_signature': 4},
#  {'danceability': 0.587,
#   'energy': 0.365,
#   'key': 0,
#   'loudness': -10.097,
#   'mode': 0,
#   'speechiness': 0.0283,
#   'acousticness': 0.666,
#   'instrumentalness': 0.211,
#   'liveness': 0.103,
#   'valence': 0.249,
#   'tempo': 76.006,
#   'type': 'audio_features',
#   'id': '0S6p2bdkHtP40s6zohvbFZ',
#   'uri': 'spotify:track:0S6p2bdkHtP40s6zohvbFZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/0S6p2bdkHtP40s6zohvbFZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0S6p2bdkHtP40s6zohvbFZ',
#   'duration_ms': 197173,
#   'time_signature': 4},
#  {'danceability': 0.527,
#   'energy': 0.578,
#   'key': 7,
#   'loudness': -5.51,
#   'mode': 1,
#   'speechiness': 0.0686,
#   'acousticness': 0.639,
#   'instrumentalness': 0.00096,
#   'liveness': 0.149,
#   'valence': 0.146,
#   'tempo': 135.054,
#   'type': 'audio_features',
#   'id': '4jTogtan0EOUJe9T3aUuld',
#   'uri': 'spotify:track:4jTogtan0EOUJe9T3aUuld',
#   'track_href': 'https://api.spotify.com/v1/tracks/4jTogtan0EOUJe9T3aUuld',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4jTogtan0EOUJe9T3aUuld',
#   'duration_ms': 218893,
#   'time_signature': 4},
#  {'danceability': 0.649,
#   'energy': 0.6,
#   'key': 6,
#   'loudness': -6.36,
#   'mode': 1,
#   'speechiness': 0.0392,
#   'acousticness': 0.0312,
#   'instrumentalness': 2.82e-06,
#   'liveness': 0.188,
#   'valence': 0.196,
#   'tempo': 116.872,
#   'type': 'audio_features',
#   'id': '4DkBBbGVFOFZNGdhekfDgy',
#   'uri': 'spotify:track:4DkBBbGVFOFZNGdhekfDgy',
#   'track_href': 'https://api.spotify.com/v1/tracks/4DkBBbGVFOFZNGdhekfDgy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4DkBBbGVFOFZNGdhekfDgy',
#   'duration_ms': 234467,
#   'time_signature': 4},
#  {'danceability': 0.603,
#   'energy': 0.324,
#   'key': 6,
#   'loudness': -8.17,
#   'mode': 1,
#   'speechiness': 0.029,
#   'acousticness': 0.621,
#   'instrumentalness': 8.55e-05,
#   'liveness': 0.116,
#   'valence': 0.073,
#   'tempo': 62.481,
#   'type': 'audio_features',
#   'id': '2uidthm3zdOzcjXgeUyNK2',
#   'uri': 'spotify:track:2uidthm3zdOzcjXgeUyNK2',
#   'track_href': 'https://api.spotify.com/v1/tracks/2uidthm3zdOzcjXgeUyNK2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2uidthm3zdOzcjXgeUyNK2',
#   'duration_ms': 266213,
#   'time_signature': 4},
#  {'danceability': 0.605,
#   'energy': 0.454,
#   'key': 2,
#   'loudness': -10.115,
#   'mode': 0,
#   'speechiness': 0.0322,
#   'acousticness': 0.485,
#   'instrumentalness': 0.0012,
#   'liveness': 0.108,
#   'valence': 0.312,
#   'tempo': 140.107,
#   'type': 'audio_features',
#   'id': '61pnMa2mEMpQoVYxXUD1jT',
#   'uri': 'spotify:track:61pnMa2mEMpQoVYxXUD1jT',
#   'track_href': 'https://api.spotify.com/v1/tracks/61pnMa2mEMpQoVYxXUD1jT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/61pnMa2mEMpQoVYxXUD1jT',
#   'duration_ms': 242147,
#   'time_signature': 4},
#  {'danceability': 0.622,
#   'energy': 0.191,
#   'key': 6,
#   'loudness': -11.197,
#   'mode': 0,
#   'speechiness': 0.0438,
#   'acousticness': 0.858,
#   'instrumentalness': 1.58e-06,
#   'liveness': 0.0885,
#   'valence': 0.149,
#   'tempo': 99.435,
#   'type': 'audio_features',
#   'id': '4FKwaxYGCcUdwc3GxAG2pY',
#   'uri': 'spotify:track:4FKwaxYGCcUdwc3GxAG2pY',
#   'track_href': 'https://api.spotify.com/v1/tracks/4FKwaxYGCcUdwc3GxAG2pY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4FKwaxYGCcUdwc3GxAG2pY',
#   'duration_ms': 219480,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.897,
#   'key': 2,
#   'loudness': -5.959,
#   'mode': 1,
#   'speechiness': 0.0288,
#   'acousticness': 0.0457,
#   'instrumentalness': 9.09e-05,
#   'liveness': 0.321,
#   'valence': 0.965,
#   'tempo': 123.941,
#   'type': 'audio_features',
#   'id': '3rvXqioUPvUxH089LaqeDy',
#   'uri': 'spotify:track:3rvXqioUPvUxH089LaqeDy',
#   'track_href': 'https://api.spotify.com/v1/tracks/3rvXqioUPvUxH089LaqeDy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3rvXqioUPvUxH089LaqeDy',
#   'duration_ms': 237129,
#   'time_signature': 4},
#  {'danceability': 0.598,
#   'energy': 0.939,
#   'key': 7,
#   'loudness': -3.404,
#   'mode': 0,
#   'speechiness': 0.0497,
#   'acousticness': 0.0453,
#   'instrumentalness': 0.00248,
#   'liveness': 0.0877,
#   'valence': 0.895,
#   'tempo': 171.992,
#   'type': 'audio_features',
#   'id': '6svmAudSOwwFUdI6ySWmV9',
#   'uri': 'spotify:track:6svmAudSOwwFUdI6ySWmV9',
#   'track_href': 'https://api.spotify.com/v1/tracks/6svmAudSOwwFUdI6ySWmV9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6svmAudSOwwFUdI6ySWmV9',
#   'duration_ms': 237216,
#   'time_signature': 4},
#  {'danceability': 0.708,
#   'energy': 0.896,
#   'key': 2,
#   'loudness': -4.918,
#   'mode': 1,
#   'speechiness': 0.0323,
#   'acousticness': 0.0542,
#   'instrumentalness': 0,
#   'liveness': 0.193,
#   'valence': 0.96,
#   'tempo': 139.97,
#   'type': 'audio_features',
#   'id': '7zdeRaN0IoTeT7oq3ahfQj',
#   'uri': 'spotify:track:7zdeRaN0IoTeT7oq3ahfQj',
#   'track_href': 'https://api.spotify.com/v1/tracks/7zdeRaN0IoTeT7oq3ahfQj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7zdeRaN0IoTeT7oq3ahfQj',
#   'duration_ms': 230536,
#   'time_signature': 4},
#  {'danceability': 0.69,
#   'energy': 0.861,
#   'key': 2,
#   'loudness': -3.882,
#   'mode': 1,
#   'speechiness': 0.0542,
#   'acousticness': 0.0322,
#   'instrumentalness': 0,
#   'liveness': 0.0899,
#   'valence': 0.38,
#   'tempo': 88.975,
#   'type': 'audio_features',
#   'id': '1Beh1HcYoLUOyC036SrhGB',
#   'uri': 'spotify:track:1Beh1HcYoLUOyC036SrhGB',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Beh1HcYoLUOyC036SrhGB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Beh1HcYoLUOyC036SrhGB',
#   'duration_ms': 164552,
#   'time_signature': 4},
#  {'danceability': 0.551,
#   'energy': 0.773,
#   'key': 7,
#   'loudness': -5.824,
#   'mode': 1,
#   'speechiness': 0.0471,
#   'acousticness': 0.0897,
#   'instrumentalness': 0,
#   'liveness': 0.181,
#   'valence': 0.63,
#   'tempo': 170.001,
#   'type': 'audio_features',
#   'id': '4GZA07xlzRg46sG0wAfeuM',
#   'uri': 'spotify:track:4GZA07xlzRg46sG0wAfeuM',
#   'track_href': 'https://api.spotify.com/v1/tracks/4GZA07xlzRg46sG0wAfeuM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4GZA07xlzRg46sG0wAfeuM',
#   'duration_ms': 218824,
#   'time_signature': 4},
#  {'danceability': 0.779,
#   'energy': 0.911,
#   'key': 7,
#   'loudness': -4.553,
#   'mode': 0,
#   'speechiness': 0.038,
#   'acousticness': 0.0155,
#   'instrumentalness': 0,
#   'liveness': 0.0925,
#   'valence': 0.975,
#   'tempo': 140.019,
#   'type': 'audio_features',
#   'id': '3h5HYrVyuQk0IhsDhG8J9U',
#   'uri': 'spotify:track:3h5HYrVyuQk0IhsDhG8J9U',
#   'track_href': 'https://api.spotify.com/v1/tracks/3h5HYrVyuQk0IhsDhG8J9U',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3h5HYrVyuQk0IhsDhG8J9U',
#   'duration_ms': 222000,
#   'time_signature': 4},
#  {'danceability': 0.842,
#   'energy': 0.565,
#   'key': 4,
#   'loudness': -6.395,
#   'mode': 1,
#   'speechiness': 0.354,
#   'acousticness': 0.415,
#   'instrumentalness': 0,
#   'liveness': 0.168,
#   'valence': 0.962,
#   'tempo': 85.003,
#   'type': 'audio_features',
#   'id': '6tKahO6bgLc1dZzL6EyGoi',
#   'uri': 'spotify:track:6tKahO6bgLc1dZzL6EyGoi',
#   'track_href': 'https://api.spotify.com/v1/tracks/6tKahO6bgLc1dZzL6EyGoi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6tKahO6bgLc1dZzL6EyGoi',
#   'duration_ms': 117184,
#   'time_signature': 4},
#  {'danceability': 0.539,
#   'energy': 0.901,
#   'key': 1,
#   'loudness': -4.077,
#   'mode': 0,
#   'speechiness': 0.0433,
#   'acousticness': 0.0139,
#   'instrumentalness': 0,
#   'liveness': 0.0726,
#   'valence': 0.801,
#   'tempo': 172.966,
#   'type': 'audio_features',
#   'id': '7p6m7n8BPeGFAeLphvbz70',
#   'uri': 'spotify:track:7p6m7n8BPeGFAeLphvbz70',
#   'track_href': 'https://api.spotify.com/v1/tracks/7p6m7n8BPeGFAeLphvbz70',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7p6m7n8BPeGFAeLphvbz70',
#   'duration_ms': 228579,
#   'time_signature': 4},
#  {'danceability': 0.72,
#   'energy': 0.93,
#   'key': 1,
#   'loudness': -3.798,
#   'mode': 1,
#   'speechiness': 0.0342,
#   'acousticness': 0.00496,
#   'instrumentalness': 0.000138,
#   'liveness': 0.171,
#   'valence': 0.756,
#   'tempo': 125.012,
#   'type': 'audio_features',
#   'id': '1bf2znJ3TEZWODV3EuXGQK',
#   'uri': 'spotify:track:1bf2znJ3TEZWODV3EuXGQK',
#   'track_href': 'https://api.spotify.com/v1/tracks/1bf2znJ3TEZWODV3EuXGQK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1bf2znJ3TEZWODV3EuXGQK',
#   'duration_ms': 184319,
#   'time_signature': 4},
#  {'danceability': 0.669,
#   'energy': 0.747,
#   'key': 5,
#   'loudness': -5.743,
#   'mode': 1,
#   'speechiness': 0.0286,
#   'acousticness': 0.243,
#   'instrumentalness': 0,
#   'liveness': 0.102,
#   'valence': 0.859,
#   'tempo': 100.02,
#   'type': 'audio_features',
#   'id': '4BcBaSCzDqtgbyWdoNmchH',
#   'uri': 'spotify:track:4BcBaSCzDqtgbyWdoNmchH',
#   'track_href': 'https://api.spotify.com/v1/tracks/4BcBaSCzDqtgbyWdoNmchH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4BcBaSCzDqtgbyWdoNmchH',
#   'duration_ms': 245550,
#   'time_signature': 4},
#  {'danceability': 0.611,
#   'energy': 0.656,
#   'key': 2,
#   'loudness': -6.287,
#   'mode': 1,
#   'speechiness': 0.0586,
#   'acousticness': 0.0788,
#   'instrumentalness': 0,
#   'liveness': 0.0747,
#   'valence': 0.576,
#   'tempo': 147.027,
#   'type': 'audio_features',
#   'id': '5NPHXWQJlsXb5DvkTGcrCS',
#   'uri': 'spotify:track:5NPHXWQJlsXb5DvkTGcrCS',
#   'track_href': 'https://api.spotify.com/v1/tracks/5NPHXWQJlsXb5DvkTGcrCS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5NPHXWQJlsXb5DvkTGcrCS',
#   'duration_ms': 229932,
#   'time_signature': 4},
#  {'danceability': 0.74,
#   'energy': 0.738,
#   'key': 1,
#   'loudness': -6.068,
#   'mode': 1,
#   'speechiness': 0.237,
#   'acousticness': 0.103,
#   'instrumentalness': 0,
#   'liveness': 0.0912,
#   'valence': 0.545,
#   'tempo': 128.079,
#   'type': 'audio_features',
#   'id': '5pa2lWxWk7UOCQBMKagKnt',
#   'uri': 'spotify:track:5pa2lWxWk7UOCQBMKagKnt',
#   'track_href': 'https://api.spotify.com/v1/tracks/5pa2lWxWk7UOCQBMKagKnt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5pa2lWxWk7UOCQBMKagKnt',
#   'duration_ms': 188730,
#   'time_signature': 4},
#  {'danceability': 0.629,
#   'energy': 0.864,
#   'key': 7,
#   'loudness': -5.785,
#   'mode': 1,
#   'speechiness': 0.15,
#   'acousticness': 0.299,
#   'instrumentalness': 0,
#   'liveness': 0.745,
#   'valence': 0.602,
#   'tempo': 97.067,
#   'type': 'audio_features',
#   'id': '6nQWhfXUt8iUVqxIUGTFf0',
#   'uri': 'spotify:track:6nQWhfXUt8iUVqxIUGTFf0',
#   'track_href': 'https://api.spotify.com/v1/tracks/6nQWhfXUt8iUVqxIUGTFf0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6nQWhfXUt8iUVqxIUGTFf0',
#   'duration_ms': 270000,
#   'time_signature': 4},
#  {'danceability': 0.678,
#   'energy': 0.921,
#   'key': 7,
#   'loudness': -4.418,
#   'mode': 0,
#   'speechiness': 0.116,
#   'acousticness': 0.559,
#   'instrumentalness': 0,
#   'liveness': 0.163,
#   'valence': 0.723,
#   'tempo': 124.02,
#   'type': 'audio_features',
#   'id': '0DGWbcIC2DPWFC0lHNOv4o',
#   'uri': 'spotify:track:0DGWbcIC2DPWFC0lHNOv4o',
#   'track_href': 'https://api.spotify.com/v1/tracks/0DGWbcIC2DPWFC0lHNOv4o',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0DGWbcIC2DPWFC0lHNOv4o',
#   'duration_ms': 273187,
#   'time_signature': 4},
#  {'danceability': 0.536,
#   'energy': 0.74,
#   'key': 10,
#   'loudness': -7.037,
#   'mode': 0,
#   'speechiness': 0.0542,
#   'acousticness': 0.0549,
#   'instrumentalness': 0.000141,
#   'liveness': 0.232,
#   'valence': 0.346,
#   'tempo': 94.05,
#   'type': 'audio_features',
#   'id': '3RLMlKry1oEbv7VTABSMZW',
#   'uri': 'spotify:track:3RLMlKry1oEbv7VTABSMZW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3RLMlKry1oEbv7VTABSMZW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3RLMlKry1oEbv7VTABSMZW',
#   'duration_ms': 288020,
#   'time_signature': 4},
#  {'danceability': 0.603,
#   'energy': 0.802,
#   'key': 11,
#   'loudness': -5.681,
#   'mode': 0,
#   'speechiness': 0.154,
#   'acousticness': 0.343,
#   'instrumentalness': 0,
#   'liveness': 0.175,
#   'valence': 0.885,
#   'tempo': 88.853,
#   'type': 'audio_features',
#   'id': '2WsWWajw3f4hFe6NL2rEmc',
#   'uri': 'spotify:track:2WsWWajw3f4hFe6NL2rEmc',
#   'track_href': 'https://api.spotify.com/v1/tracks/2WsWWajw3f4hFe6NL2rEmc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2WsWWajw3f4hFe6NL2rEmc',
#   'duration_ms': 222250,
#   'time_signature': 4},
#  {'danceability': 0.572,
#   'energy': 0.875,
#   'key': 11,
#   'loudness': -6.828,
#   'mode': 0,
#   'speechiness': 0.227,
#   'acousticness': 0.00846,
#   'instrumentalness': 1.61e-06,
#   'liveness': 0.195,
#   'valence': 0.451,
#   'tempo': 126.052,
#   'type': 'audio_features',
#   'id': '2Zb52iyyJ0Ir6iTBp8fTYx',
#   'uri': 'spotify:track:2Zb52iyyJ0Ir6iTBp8fTYx',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Zb52iyyJ0Ir6iTBp8fTYx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Zb52iyyJ0Ir6iTBp8fTYx',
#   'duration_ms': 302540,
#   'time_signature': 4},
#  {'danceability': 0.661,
#   'energy': 0.629,
#   'key': 8,
#   'loudness': -6.882,
#   'mode': 0,
#   'speechiness': 0.188,
#   'acousticness': 0.0866,
#   'instrumentalness': 0,
#   'liveness': 0.138,
#   'valence': 0.505,
#   'tempo': 150.973,
#   'type': 'audio_features',
#   'id': '1HEvABYcyTQ5spl2AHG4CV',
#   'uri': 'spotify:track:1HEvABYcyTQ5spl2AHG4CV',
#   'track_href': 'https://api.spotify.com/v1/tracks/1HEvABYcyTQ5spl2AHG4CV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1HEvABYcyTQ5spl2AHG4CV',
#   'duration_ms': 278742,
#   'time_signature': 4},
#  {'danceability': 0.78,
#   'energy': 0.841,
#   'key': 6,
#   'loudness': -5.128,
#   'mode': 1,
#   'speechiness': 0.0557,
#   'acousticness': 0.508,
#   'instrumentalness': 0,
#   'liveness': 0.496,
#   'valence': 0.839,
#   'tempo': 109.979,
#   'type': 'audio_features',
#   'id': '5wuPThXXbfDmJFYCfFHeHV',
#   'uri': 'spotify:track:5wuPThXXbfDmJFYCfFHeHV',
#   'track_href': 'https://api.spotify.com/v1/tracks/5wuPThXXbfDmJFYCfFHeHV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5wuPThXXbfDmJFYCfFHeHV',
#   'duration_ms': 267545,
#   'time_signature': 4},
#  {'danceability': 0.71,
#   'energy': 0.698,
#   'key': 2,
#   'loudness': -6.317,
#   'mode': 1,
#   'speechiness': 0.159,
#   'acousticness': 0.498,
#   'instrumentalness': 0,
#   'liveness': 0.252,
#   'valence': 0.56,
#   'tempo': 90.335,
#   'type': 'audio_features',
#   'id': '1ixxfiTOXw8yAmbUcPdFDk',
#   'uri': 'spotify:track:1ixxfiTOXw8yAmbUcPdFDk',
#   'track_href': 'https://api.spotify.com/v1/tracks/1ixxfiTOXw8yAmbUcPdFDk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ixxfiTOXw8yAmbUcPdFDk',
#   'duration_ms': 275180,
#   'time_signature': 4},
#  {'danceability': 0.67,
#   'energy': 0.792,
#   'key': 10,
#   'loudness': -6.459,
#   'mode': 0,
#   'speechiness': 0.124,
#   'acousticness': 0.432,
#   'instrumentalness': 0,
#   'liveness': 0.0872,
#   'valence': 0.594,
#   'tempo': 136.03,
#   'type': 'audio_features',
#   'id': '50HfEbnKiPBECpQXh3Rvai',
#   'uri': 'spotify:track:50HfEbnKiPBECpQXh3Rvai',
#   'track_href': 'https://api.spotify.com/v1/tracks/50HfEbnKiPBECpQXh3Rvai',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50HfEbnKiPBECpQXh3Rvai',
#   'duration_ms': 399500,
#   'time_signature': 4},
#  {'danceability': 0.52,
#   'energy': 0.801,
#   'key': 5,
#   'loudness': -4.7,
#   'mode': 1,
#   'speechiness': 0.237,
#   'acousticness': 0.683,
#   'instrumentalness': 0,
#   'liveness': 0.936,
#   'valence': 0.65,
#   'tempo': 170.063,
#   'type': 'audio_features',
#   'id': '1bq8xEpCIrt3PDIEMtBZc7',
#   'uri': 'spotify:track:1bq8xEpCIrt3PDIEMtBZc7',
#   'track_href': 'https://api.spotify.com/v1/tracks/1bq8xEpCIrt3PDIEMtBZc7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1bq8xEpCIrt3PDIEMtBZc7',
#   'duration_ms': 281250,
#   'time_signature': 4},
#  {'danceability': 0.518,
#   'energy': 0.601,
#   'key': 9,
#   'loudness': -11.153,
#   'mode': 0,
#   'speechiness': 0.0309,
#   'acousticness': 0.285,
#   'instrumentalness': 0.000845,
#   'liveness': 0.165,
#   'valence': 0.68,
#   'tempo': 151.847,
#   'type': 'audio_features',
#   'id': '5QuY4zIR2vbq96AZZ1Hxdh',
#   'uri': 'spotify:track:5QuY4zIR2vbq96AZZ1Hxdh',
#   'track_href': 'https://api.spotify.com/v1/tracks/5QuY4zIR2vbq96AZZ1Hxdh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5QuY4zIR2vbq96AZZ1Hxdh',
#   'duration_ms': 221000,
#   'time_signature': 5},
#  {'danceability': 0.697,
#   'energy': 0.369,
#   'key': 0,
#   'loudness': -12.856,
#   'mode': 1,
#   'speechiness': 0.0252,
#   'acousticness': 0.439,
#   'instrumentalness': 0.00143,
#   'liveness': 0.104,
#   'valence': 0.606,
#   'tempo': 95.971,
#   'type': 'audio_features',
#   'id': '79bhJ8vEiEgsJUzy5jeaVV',
#   'uri': 'spotify:track:79bhJ8vEiEgsJUzy5jeaVV',
#   'track_href': 'https://api.spotify.com/v1/tracks/79bhJ8vEiEgsJUzy5jeaVV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/79bhJ8vEiEgsJUzy5jeaVV',
#   'duration_ms': 210250,
#   'time_signature': 4},
#  {'danceability': 0.543,
#   'energy': 0.24,
#   'key': 9,
#   'loudness': -13.489,
#   'mode': 1,
#   'speechiness': 0.0273,
#   'acousticness': 0.891,
#   'instrumentalness': 0.00821,
#   'liveness': 0.11,
#   'valence': 0.129,
#   'tempo': 94.107,
#   'type': 'audio_features',
#   'id': '4rwC8TYNGksqWLmlLP8KbR',
#   'uri': 'spotify:track:4rwC8TYNGksqWLmlLP8KbR',
#   'track_href': 'https://api.spotify.com/v1/tracks/4rwC8TYNGksqWLmlLP8KbR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4rwC8TYNGksqWLmlLP8KbR',
#   'duration_ms': 256000,
#   'time_signature': 3},
#  {'danceability': 0.672,
#   'energy': 0.275,
#   'key': 7,
#   'loudness': -11.601,
#   'mode': 1,
#   'speechiness': 0.0272,
#   'acousticness': 0.735,
#   'instrumentalness': 1e-06,
#   'liveness': 0.0633,
#   'valence': 0.447,
#   'tempo': 113.912,
#   'type': 'audio_features',
#   'id': '1Ky7BSUiO3mrGsTjY3PZp9',
#   'uri': 'spotify:track:1Ky7BSUiO3mrGsTjY3PZp9',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Ky7BSUiO3mrGsTjY3PZp9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Ky7BSUiO3mrGsTjY3PZp9',
#   'duration_ms': 265750,
#   'time_signature': 3},
#  {'danceability': 0.421,
#   'energy': 0.449,
#   'key': 7,
#   'loudness': -11.683,
#   'mode': 0,
#   'speechiness': 0.0318,
#   'acousticness': 0.681,
#   'instrumentalness': 0,
#   'liveness': 0.131,
#   'valence': 0.572,
#   'tempo': 93.651,
#   'type': 'audio_features',
#   'id': '71iP4QSJtkEWkrhSqRBdA3',
#   'uri': 'spotify:track:71iP4QSJtkEWkrhSqRBdA3',
#   'track_href': 'https://api.spotify.com/v1/tracks/71iP4QSJtkEWkrhSqRBdA3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/71iP4QSJtkEWkrhSqRBdA3',
#   'duration_ms': 230500,
#   'time_signature': 4},
#  {'danceability': 0.627,
#   'energy': 0.427,
#   'key': 5,
#   'loudness': -13.683,
#   'mode': 0,
#   'speechiness': 0.0411,
#   'acousticness': 0.27,
#   'instrumentalness': 0.0101,
#   'liveness': 0.191,
#   'valence': 0.906,
#   'tempo': 175.942,
#   'type': 'audio_features',
#   'id': '6w63JPQufIhiipjqDKnamx',
#   'uri': 'spotify:track:6w63JPQufIhiipjqDKnamx',
#   'track_href': 'https://api.spotify.com/v1/tracks/6w63JPQufIhiipjqDKnamx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6w63JPQufIhiipjqDKnamx',
#   'duration_ms': 177000,
#   'time_signature': 4},
#  {'danceability': 0.594,
#   'energy': 0.174,
#   'key': 7,
#   'loudness': -12.332,
#   'mode': 0,
#   'speechiness': 0.0321,
#   'acousticness': 0.823,
#   'instrumentalness': 3.42e-05,
#   'liveness': 0.131,
#   'valence': 0.136,
#   'tempo': 119.956,
#   'type': 'audio_features',
#   'id': '6M2GcZvlATUssDJ3BmzZZh',
#   'uri': 'spotify:track:6M2GcZvlATUssDJ3BmzZZh',
#   'track_href': 'https://api.spotify.com/v1/tracks/6M2GcZvlATUssDJ3BmzZZh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6M2GcZvlATUssDJ3BmzZZh',
#   'duration_ms': 218000,
#   'time_signature': 4},
#  {'danceability': 0.411,
#   'energy': 0.691,
#   'key': 7,
#   'loudness': -10.236,
#   'mode': 0,
#   'speechiness': 0.0365,
#   'acousticness': 0.399,
#   'instrumentalness': 0.39,
#   'liveness': 0.0959,
#   'valence': 0.36,
#   'tempo': 165.031,
#   'type': 'audio_features',
#   'id': '3VTN5PzK0T99YQ7YX6kI23',
#   'uri': 'spotify:track:3VTN5PzK0T99YQ7YX6kI23',
#   'track_href': 'https://api.spotify.com/v1/tracks/3VTN5PzK0T99YQ7YX6kI23',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3VTN5PzK0T99YQ7YX6kI23',
#   'duration_ms': 188000,
#   'time_signature': 3},
#  {'danceability': 0.691,
#   'energy': 0.511,
#   'key': 0,
#   'loudness': -11.21,
#   'mode': 0,
#   'speechiness': 0.0369,
#   'acousticness': 0.229,
#   'instrumentalness': 0.00016,
#   'liveness': 0.305,
#   'valence': 0.921,
#   'tempo': 163.919,
#   'type': 'audio_features',
#   'id': '1iEYmVxPus9Yrcj0Vyagin',
#   'uri': 'spotify:track:1iEYmVxPus9Yrcj0Vyagin',
#   'track_href': 'https://api.spotify.com/v1/tracks/1iEYmVxPus9Yrcj0Vyagin',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1iEYmVxPus9Yrcj0Vyagin',
#   'duration_ms': 172000,
#   'time_signature': 3},
#  {'danceability': 0.665,
#   'energy': 0.156,
#   'key': 9,
#   'loudness': -14.938,
#   'mode': 1,
#   'speechiness': 0.0351,
#   'acousticness': 0.834,
#   'instrumentalness': 0.000249,
#   'liveness': 0.108,
#   'valence': 0.621,
#   'tempo': 106.508,
#   'type': 'audio_features',
#   'id': '5p41CLFdFz93FqKIWXq1vB',
#   'uri': 'spotify:track:5p41CLFdFz93FqKIWXq1vB',
#   'track_href': 'https://api.spotify.com/v1/tracks/5p41CLFdFz93FqKIWXq1vB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5p41CLFdFz93FqKIWXq1vB',
#   'duration_ms': 266000,
#   'time_signature': 3},
#  {'danceability': 0.417,
#   'energy': 0.0812,
#   'key': 7,
#   'loudness': -18.375,
#   'mode': 0,
#   'speechiness': 0.0961,
#   'acousticness': 0.787,
#   'instrumentalness': 0,
#   'liveness': 0.131,
#   'valence': 0.0716,
#   'tempo': 90.528,
#   'type': 'audio_features',
#   'id': '2LNGyxYvhfRsryCDhBxh4F',
#   'uri': 'spotify:track:2LNGyxYvhfRsryCDhBxh4F',
#   'track_href': 'https://api.spotify.com/v1/tracks/2LNGyxYvhfRsryCDhBxh4F',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2LNGyxYvhfRsryCDhBxh4F',
#   'duration_ms': 100000,
#   'time_signature': 4},
#  {'danceability': 0.685,
#   'energy': 0.315,
#   'key': 6,
#   'loudness': -14.629,
#   'mode': 0,
#   'speechiness': 0.029,
#   'acousticness': 0.832,
#   'instrumentalness': 0.00436,
#   'liveness': 0.0976,
#   'valence': 0.321,
#   'tempo': 114.982,
#   'type': 'audio_features',
#   'id': '12VQ7d8iczfxFEAf4TLJ3L',
#   'uri': 'spotify:track:12VQ7d8iczfxFEAf4TLJ3L',
#   'track_href': 'https://api.spotify.com/v1/tracks/12VQ7d8iczfxFEAf4TLJ3L',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/12VQ7d8iczfxFEAf4TLJ3L',
#   'duration_ms': 323000,
#   'time_signature': 3},
#  {'danceability': 0.498,
#   'energy': 0.18,
#   'key': 4,
#   'loudness': -14.391,
#   'mode': 1,
#   'speechiness': 0.0363,
#   'acousticness': 0.953,
#   'instrumentalness': 0.000549,
#   'liveness': 0.102,
#   'valence': 0.0713,
#   'tempo': 95.754,
#   'type': 'audio_features',
#   'id': '1UL1QUbMUDwTLoDgjXINtT',
#   'uri': 'spotify:track:1UL1QUbMUDwTLoDgjXINtT',
#   'track_href': 'https://api.spotify.com/v1/tracks/1UL1QUbMUDwTLoDgjXINtT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1UL1QUbMUDwTLoDgjXINtT',
#   'duration_ms': 302000,
#   'time_signature': 4},
#  {'danceability': 0.823,
#   'energy': 0.531,
#   'key': 5,
#   'loudness': -7.036,
#   'mode': 0,
#   'speechiness': 0.0416,
#   'acousticness': 0.0185,
#   'instrumentalness': 0.275,
#   'liveness': 0.106,
#   'valence': 0.692,
#   'tempo': 140.018,
#   'type': 'audio_features',
#   'id': '3JFr2IWH2PeuhGTgfwVSEf',
#   'uri': 'spotify:track:3JFr2IWH2PeuhGTgfwVSEf',
#   'track_href': 'https://api.spotify.com/v1/tracks/3JFr2IWH2PeuhGTgfwVSEf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3JFr2IWH2PeuhGTgfwVSEf',
#   'duration_ms': 249750,
#   'time_signature': 4},
#  {'danceability': 0.505,
#   'energy': 0.722,
#   'key': 2,
#   'loudness': -6.112,
#   'mode': 1,
#   'speechiness': 0.0781,
#   'acousticness': 0.0473,
#   'instrumentalness': 0.000246,
#   'liveness': 0.078,
#   'valence': 0.869,
#   'tempo': 176.149,
#   'type': 'audio_features',
#   'id': '16fzDIdGQehV2jiW5KqaGJ',
#   'uri': 'spotify:track:16fzDIdGQehV2jiW5KqaGJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/16fzDIdGQehV2jiW5KqaGJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/16fzDIdGQehV2jiW5KqaGJ',
#   'duration_ms': 205377,
#   'time_signature': 4},
#  {'danceability': 0.51,
#   'energy': 0.775,
#   'key': 0,
#   'loudness': -6.716,
#   'mode': 0,
#   'speechiness': 0.032,
#   'acousticness': 0.0263,
#   'instrumentalness': 0.00608,
#   'liveness': 0.071,
#   'valence': 0.878,
#   'tempo': 168.04,
#   'type': 'audio_features',
#   'id': '2u01roQVib48DUstSbCz90',
#   'uri': 'spotify:track:2u01roQVib48DUstSbCz90',
#   'track_href': 'https://api.spotify.com/v1/tracks/2u01roQVib48DUstSbCz90',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2u01roQVib48DUstSbCz90',
#   'duration_ms': 258151,
#   'time_signature': 4},
#  {'danceability': 0.729,
#   'energy': 0.317,
#   'key': 10,
#   'loudness': -10.713,
#   'mode': 0,
#   'speechiness': 0.0342,
#   'acousticness': 0.601,
#   'instrumentalness': 0.00905,
#   'liveness': 0.104,
#   'valence': 0.406,
#   'tempo': 121.951,
#   'type': 'audio_features',
#   'id': '4V3dVenCthSf8HvRP5pTrm',
#   'uri': 'spotify:track:4V3dVenCthSf8HvRP5pTrm',
#   'track_href': 'https://api.spotify.com/v1/tracks/4V3dVenCthSf8HvRP5pTrm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4V3dVenCthSf8HvRP5pTrm',
#   'duration_ms': 313783,
#   'time_signature': 4},
#  {'danceability': 0.699,
#   'energy': 0.53,
#   'key': 0,
#   'loudness': -8.245,
#   'mode': 0,
#   'speechiness': 0.0275,
#   'acousticness': 0.467,
#   'instrumentalness': 0.0551,
#   'liveness': 0.124,
#   'valence': 0.683,
#   'tempo': 102.993,
#   'type': 'audio_features',
#   'id': '2WcIZtZ6nNAkzTY5Zy110M',
#   'uri': 'spotify:track:2WcIZtZ6nNAkzTY5Zy110M',
#   'track_href': 'https://api.spotify.com/v1/tracks/2WcIZtZ6nNAkzTY5Zy110M',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2WcIZtZ6nNAkzTY5Zy110M',
#   'duration_ms': 293649,
#   'time_signature': 4},
#  {'danceability': 0.527,
#   'energy': 0.429,
#   'key': 0,
#   'loudness': -6.788,
#   'mode': 0,
#   'speechiness': 0.0369,
#   'acousticness': 0.491,
#   'instrumentalness': 0.00748,
#   'liveness': 0.11,
#   'valence': 0.679,
#   'tempo': 170.184,
#   'type': 'audio_features',
#   'id': '7nl22KBijYGX7EJrgEXly3',
#   'uri': 'spotify:track:7nl22KBijYGX7EJrgEXly3',
#   'track_href': 'https://api.spotify.com/v1/tracks/7nl22KBijYGX7EJrgEXly3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7nl22KBijYGX7EJrgEXly3',
#   'duration_ms': 243768,
#   'time_signature': 4},
#  {'danceability': 0.548,
#   'energy': 0.859,
#   'key': 7,
#   'loudness': -4.008,
#   'mode': 1,
#   'speechiness': 0.0498,
#   'acousticness': 0.0628,
#   'instrumentalness': 0.141,
#   'liveness': 0.14,
#   'valence': 0.911,
#   'tempo': 126.978,
#   'type': 'audio_features',
#   'id': '1SFxGjegYtEPBKkVUYKLTB',
#   'uri': 'spotify:track:1SFxGjegYtEPBKkVUYKLTB',
#   'track_href': 'https://api.spotify.com/v1/tracks/1SFxGjegYtEPBKkVUYKLTB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1SFxGjegYtEPBKkVUYKLTB',
#   'duration_ms': 221700,
#   'time_signature': 4},
#  {'danceability': 0.622,
#   'energy': 0.284,
#   'key': 9,
#   'loudness': -9.365,
#   'mode': 0,
#   'speechiness': 0.0399,
#   'acousticness': 0.911,
#   'instrumentalness': 0.0682,
#   'liveness': 0.119,
#   'valence': 0.437,
#   'tempo': 113.239,
#   'type': 'audio_features',
#   'id': '6aRwnAwJNHBlpDOdh6fhpN',
#   'uri': 'spotify:track:6aRwnAwJNHBlpDOdh6fhpN',
#   'track_href': 'https://api.spotify.com/v1/tracks/6aRwnAwJNHBlpDOdh6fhpN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6aRwnAwJNHBlpDOdh6fhpN',
#   'duration_ms': 318431,
#   'time_signature': 4},
#  {'danceability': 0.573,
#   'energy': 0.618,
#   'key': 10,
#   'loudness': -6.152,
#   'mode': 1,
#   'speechiness': 0.0289,
#   'acousticness': 0.00507,
#   'instrumentalness': 0.0318,
#   'liveness': 0.0467,
#   'valence': 0.795,
#   'tempo': 126.987,
#   'type': 'audio_features',
#   'id': '6KxKBULBBJhPJiKt3RZwMW',
#   'uri': 'spotify:track:6KxKBULBBJhPJiKt3RZwMW',
#   'track_href': 'https://api.spotify.com/v1/tracks/6KxKBULBBJhPJiKt3RZwMW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6KxKBULBBJhPJiKt3RZwMW',
#   'duration_ms': 230673,
#   'time_signature': 4},
#  {'danceability': 0.564,
#   'energy': 0.359,
#   'key': 0,
#   'loudness': -8.846,
#   'mode': 0,
#   'speechiness': 0.0766,
#   'acousticness': 0.634,
#   'instrumentalness': 0.000191,
#   'liveness': 0.115,
#   'valence': 0.773,
#   'tempo': 94.597,
#   'type': 'audio_features',
#   'id': '7MOOhBRUaUmXDHVjdwKzBn',
#   'uri': 'spotify:track:7MOOhBRUaUmXDHVjdwKzBn',
#   'track_href': 'https://api.spotify.com/v1/tracks/7MOOhBRUaUmXDHVjdwKzBn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7MOOhBRUaUmXDHVjdwKzBn',
#   'duration_ms': 190095,
#   'time_signature': 4},
#  {'danceability': 0.669,
#   'energy': 0.567,
#   'key': 7,
#   'loudness': -5.133,
#   'mode': 1,
#   'speechiness': 0.12,
#   'acousticness': 0.00292,
#   'instrumentalness': 0.473,
#   'liveness': 0.12,
#   'valence': 0.449,
#   'tempo': 169.928,
#   'type': 'audio_features',
#   'id': '4BLvBgts2Gvuyh2YFtH8qM',
#   'uri': 'spotify:track:4BLvBgts2Gvuyh2YFtH8qM',
#   'track_href': 'https://api.spotify.com/v1/tracks/4BLvBgts2Gvuyh2YFtH8qM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4BLvBgts2Gvuyh2YFtH8qM',
#   'duration_ms': 163347,
#   'time_signature': 4},
#  {'danceability': 0.728,
#   'energy': 0.635,
#   'key': 1,
#   'loudness': -5.422,
#   'mode': 0,
#   'speechiness': 0.0394,
#   'acousticness': 0.0327,
#   'instrumentalness': 0.000576,
#   'liveness': 0.136,
#   'valence': 0.354,
#   'tempo': 141.922,
#   'type': 'audio_features',
#   'id': '6LwBFoBcDfSOAQ0McrGgYk',
#   'uri': 'spotify:track:6LwBFoBcDfSOAQ0McrGgYk',
#   'track_href': 'https://api.spotify.com/v1/tracks/6LwBFoBcDfSOAQ0McrGgYk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6LwBFoBcDfSOAQ0McrGgYk',
#   'duration_ms': 173440,
#   'time_signature': 4},
#  {'danceability': 0.654,
#   'energy': 0.576,
#   'key': 7,
#   'loudness': -6.223,
#   'mode': 0,
#   'speechiness': 0.0923,
#   'acousticness': 0.384,
#   'instrumentalness': 0,
#   'liveness': 0.116,
#   'valence': 0.248,
#   'tempo': 139.901,
#   'type': 'audio_features',
#   'id': '5oHq9uc3BnKBl1pmvIjJLA',
#   'uri': 'spotify:track:5oHq9uc3BnKBl1pmvIjJLA',
#   'track_href': 'https://api.spotify.com/v1/tracks/5oHq9uc3BnKBl1pmvIjJLA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5oHq9uc3BnKBl1pmvIjJLA',
#   'duration_ms': 161067,
#   'time_signature': 4},
#  {'danceability': 0.789,
#   'energy': 0.853,
#   'key': 2,
#   'loudness': -4.47,
#   'mode': 0,
#   'speechiness': 0.0517,
#   'acousticness': 0.0577,
#   'instrumentalness': 7.74e-05,
#   'liveness': 0.0578,
#   'valence': 0.561,
#   'tempo': 120.04,
#   'type': 'audio_features',
#   'id': '670gd37RWZjfOpQAdZQAQu',
#   'uri': 'spotify:track:670gd37RWZjfOpQAdZQAQu',
#   'track_href': 'https://api.spotify.com/v1/tracks/670gd37RWZjfOpQAdZQAQu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/670gd37RWZjfOpQAdZQAQu',
#   'duration_ms': 167827,
#   'time_signature': 4},
#  {'danceability': 0.665,
#   'energy': 0.81,
#   'key': 4,
#   'loudness': -5.753,
#   'mode': 0,
#   'speechiness': 0.0683,
#   'acousticness': 0.0376,
#   'instrumentalness': 2.01e-05,
#   'liveness': 0.176,
#   'valence': 0.453,
#   'tempo': 130.042,
#   'type': 'audio_features',
#   'id': '5XDyLF7zTwKadIORFnk2n6',
#   'uri': 'spotify:track:5XDyLF7zTwKadIORFnk2n6',
#   'track_href': 'https://api.spotify.com/v1/tracks/5XDyLF7zTwKadIORFnk2n6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5XDyLF7zTwKadIORFnk2n6',
#   'duration_ms': 200680,
#   'time_signature': 4},
#  {'danceability': 0.589,
#   'energy': 0.491,
#   'key': 1,
#   'loudness': -6.693,
#   'mode': 1,
#   'speechiness': 0.269,
#   'acousticness': 0.0763,
#   'instrumentalness': 0.000114,
#   'liveness': 0.0977,
#   'valence': 0.261,
#   'tempo': 104.944,
#   'type': 'audio_features',
#   'id': '4IVlkdE0zQdP56iZiHn5rL',
#   'uri': 'spotify:track:4IVlkdE0zQdP56iZiHn5rL',
#   'track_href': 'https://api.spotify.com/v1/tracks/4IVlkdE0zQdP56iZiHn5rL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4IVlkdE0zQdP56iZiHn5rL',
#   'duration_ms': 152147,
#   'time_signature': 5},
#  {'danceability': 0.794,
#   'energy': 0.621,
#   'key': 7,
#   'loudness': -5.297,
#   'mode': 0,
#   'speechiness': 0.103,
#   'acousticness': 0.176,
#   'instrumentalness': 0.0254,
#   'liveness': 0.247,
#   'valence': 0.439,
#   'tempo': 119.914,
#   'type': 'audio_features',
#   'id': '6WlkV3Sz4gtTMM85Rbc5sx',
#   'uri': 'spotify:track:6WlkV3Sz4gtTMM85Rbc5sx',
#   'track_href': 'https://api.spotify.com/v1/tracks/6WlkV3Sz4gtTMM85Rbc5sx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6WlkV3Sz4gtTMM85Rbc5sx',
#   'duration_ms': 178627,
#   'time_signature': 4},
#  {'danceability': 0.701,
#   'energy': 0.57,
#   'key': 1,
#   'loudness': -5.98,
#   'mode': 0,
#   'speechiness': 0.0287,
#   'acousticness': 0.0293,
#   'instrumentalness': 0.037,
#   'liveness': 0.154,
#   'valence': 0.34,
#   'tempo': 106.027,
#   'type': 'audio_features',
#   'id': '44MVx8rc0lfUp5yW9VDl2A',
#   'uri': 'spotify:track:44MVx8rc0lfUp5yW9VDl2A',
#   'track_href': 'https://api.spotify.com/v1/tracks/44MVx8rc0lfUp5yW9VDl2A',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/44MVx8rc0lfUp5yW9VDl2A',
#   'duration_ms': 207613,
#   'time_signature': 4},
#  {'danceability': 0.677,
#   'energy': 0.454,
#   'key': 1,
#   'loudness': -6.253,
#   'mode': 0,
#   'speechiness': 0.0525,
#   'acousticness': 0.0138,
#   'instrumentalness': 0.000296,
#   'liveness': 0.103,
#   'valence': 0.213,
#   'tempo': 90.057,
#   'type': 'audio_features',
#   'id': '3CZtwixJvnRkfgNOxaF3Dn',
#   'uri': 'spotify:track:3CZtwixJvnRkfgNOxaF3Dn',
#   'track_href': 'https://api.spotify.com/v1/tracks/3CZtwixJvnRkfgNOxaF3Dn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3CZtwixJvnRkfgNOxaF3Dn',
#   'duration_ms': 207547,
#   'time_signature': 4},
#  {'danceability': 0.792,
#   'energy': 0.577,
#   'key': 6,
#   'loudness': -6.066,
#   'mode': 1,
#   'speechiness': 0.0359,
#   'acousticness': 0.0354,
#   'instrumentalness': 0.00517,
#   'liveness': 0.135,
#   'valence': 0.192,
#   'tempo': 131.983,
#   'type': 'audio_features',
#   'id': '0JKGtNrkdEhQsMupKz4xZ5',
#   'uri': 'spotify:track:0JKGtNrkdEhQsMupKz4xZ5',
#   'track_href': 'https://api.spotify.com/v1/tracks/0JKGtNrkdEhQsMupKz4xZ5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0JKGtNrkdEhQsMupKz4xZ5',
#   'duration_ms': 197240,
#   'time_signature': 4},
#  {'danceability': 0.542,
#   'energy': 0.8,
#   'key': 7,
#   'loudness': -3.912,
#   'mode': 0,
#   'speechiness': 0.0937,
#   'acousticness': 0.305,
#   'instrumentalness': 0.00146,
#   'liveness': 0.0704,
#   'valence': 0.488,
#   'tempo': 153.03,
#   'type': 'audio_features',
#   'id': '1JBHJBOr0UKTzHK0XzTII5',
#   'uri': 'spotify:track:1JBHJBOr0UKTzHK0XzTII5',
#   'track_href': 'https://api.spotify.com/v1/tracks/1JBHJBOr0UKTzHK0XzTII5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1JBHJBOr0UKTzHK0XzTII5',
#   'duration_ms': 192413,
#   'time_signature': 4},
#  {'danceability': 0.61,
#   'energy': 0.433,
#   'key': 2,
#   'loudness': -7.59,
#   'mode': 1,
#   'speechiness': 0.0296,
#   'acousticness': 0.112,
#   'instrumentalness': 0,
#   'liveness': 0.108,
#   'valence': 0.271,
#   'tempo': 113.069,
#   'type': 'audio_features',
#   'id': '0r4Gt3ItYIOTEEPgZ8POTi',
#   'uri': 'spotify:track:0r4Gt3ItYIOTEEPgZ8POTi',
#   'track_href': 'https://api.spotify.com/v1/tracks/0r4Gt3ItYIOTEEPgZ8POTi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0r4Gt3ItYIOTEEPgZ8POTi',
#   'duration_ms': 218040,
#   'time_signature': 4},
#  {'danceability': 0.543,
#   'energy': 0.439,
#   'key': 8,
#   'loudness': -13.551,
#   'mode': 1,
#   'speechiness': 0.0301,
#   'acousticness': 0.559,
#   'instrumentalness': 0.941,
#   'liveness': 0.113,
#   'valence': 0.0659,
#   'tempo': 89.97,
#   'type': 'audio_features',
#   'id': '4L46AoxxYIKY3r718kfHba',
#   'uri': 'spotify:track:4L46AoxxYIKY3r718kfHba',
#   'track_href': 'https://api.spotify.com/v1/tracks/4L46AoxxYIKY3r718kfHba',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4L46AoxxYIKY3r718kfHba',
#   'duration_ms': 288000,
#   'time_signature': 4},
#  {'danceability': 0.66,
#   'energy': 0.867,
#   'key': 2,
#   'loudness': -13.052,
#   'mode': 1,
#   'speechiness': 0.0561,
#   'acousticness': 0.00148,
#   'instrumentalness': 0.824,
#   'liveness': 0.0829,
#   'valence': 0.323,
#   'tempo': 140.034,
#   'type': 'audio_features',
#   'id': '1laF5TRKAbfuMfDHgRpa4T',
#   'uri': 'spotify:track:1laF5TRKAbfuMfDHgRpa4T',
#   'track_href': 'https://api.spotify.com/v1/tracks/1laF5TRKAbfuMfDHgRpa4T',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1laF5TRKAbfuMfDHgRpa4T',
#   'duration_ms': 255429,
#   'time_signature': 4},
#  {'danceability': 0.269,
#   'energy': 0.404,
#   'key': 6,
#   'loudness': -16.016,
#   'mode': 0,
#   'speechiness': 0.0337,
#   'acousticness': 0.0408,
#   'instrumentalness': 0.968,
#   'liveness': 0.0667,
#   'valence': 0.0868,
#   'tempo': 137.102,
#   'type': 'audio_features',
#   'id': '2i0Vk9WB10IePjBNHIoypG',
#   'uri': 'spotify:track:2i0Vk9WB10IePjBNHIoypG',
#   'track_href': 'https://api.spotify.com/v1/tracks/2i0Vk9WB10IePjBNHIoypG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2i0Vk9WB10IePjBNHIoypG',
#   'duration_ms': 244599,
#   'time_signature': 4},
#  {'danceability': 0.22,
#   'energy': 0.257,
#   'key': 1,
#   'loudness': -17.835,
#   'mode': 1,
#   'speechiness': 0.0335,
#   'acousticness': 0.604,
#   'instrumentalness': 0.877,
#   'liveness': 0.108,
#   'valence': 0.0391,
#   'tempo': 68.515,
#   'type': 'audio_features',
#   'id': '0YoNeOsJgTAfQtFr0bYEw7',
#   'uri': 'spotify:track:0YoNeOsJgTAfQtFr0bYEw7',
#   'track_href': 'https://api.spotify.com/v1/tracks/0YoNeOsJgTAfQtFr0bYEw7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0YoNeOsJgTAfQtFr0bYEw7',
#   'duration_ms': 276000,
#   'time_signature': 4},
#  {'danceability': 0.491,
#   'energy': 0.685,
#   'key': 7,
#   'loudness': -12.978,
#   'mode': 1,
#   'speechiness': 0.0385,
#   'acousticness': 0.0423,
#   'instrumentalness': 0.934,
#   'liveness': 0.112,
#   'valence': 0.156,
#   'tempo': 180.062,
#   'type': 'audio_features',
#   'id': '5dOcXPYb53xuJlBzaQpKBc',
#   'uri': 'spotify:track:5dOcXPYb53xuJlBzaQpKBc',
#   'track_href': 'https://api.spotify.com/v1/tracks/5dOcXPYb53xuJlBzaQpKBc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5dOcXPYb53xuJlBzaQpKBc',
#   'duration_ms': 370667,
#   'time_signature': 4},
#  {'danceability': 0.537,
#   'energy': 0.691,
#   'key': 7,
#   'loudness': -12.433,
#   'mode': 1,
#   'speechiness': 0.0411,
#   'acousticness': 0.141,
#   'instrumentalness': 0.88,
#   'liveness': 0.113,
#   'valence': 0.599,
#   'tempo': 139.989,
#   'type': 'audio_features',
#   'id': '4H2eE9L8X9CraVybCC2cQR',
#   'uri': 'spotify:track:4H2eE9L8X9CraVybCC2cQR',
#   'track_href': 'https://api.spotify.com/v1/tracks/4H2eE9L8X9CraVybCC2cQR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4H2eE9L8X9CraVybCC2cQR',
#   'duration_ms': 288000,
#   'time_signature': 4},
#  {'danceability': 0.53,
#   'energy': 0.821,
#   'key': 1,
#   'loudness': -12.963,
#   'mode': 1,
#   'speechiness': 0.0349,
#   'acousticness': 0.00188,
#   'instrumentalness': 0.694,
#   'liveness': 0.111,
#   'valence': 0.598,
#   'tempo': 140.015,
#   'type': 'audio_features',
#   'id': '5nknmBPKAMRxIcKLBbUE0N',
#   'uri': 'spotify:track:5nknmBPKAMRxIcKLBbUE0N',
#   'track_href': 'https://api.spotify.com/v1/tracks/5nknmBPKAMRxIcKLBbUE0N',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5nknmBPKAMRxIcKLBbUE0N',
#   'duration_ms': 197143,
#   'time_signature': 4},
#  {'danceability': 0.643,
#   'energy': 0.871,
#   'key': 9,
#   'loudness': -12.167,
#   'mode': 1,
#   'speechiness': 0.0564,
#   'acousticness': 0.0986,
#   'instrumentalness': 0.92,
#   'liveness': 0.302,
#   'valence': 0.192,
#   'tempo': 89.98,
#   'type': 'audio_features',
#   'id': '3yAf6KWkylJRIdcRm0K8G3',
#   'uri': 'spotify:track:3yAf6KWkylJRIdcRm0K8G3',
#   'track_href': 'https://api.spotify.com/v1/tracks/3yAf6KWkylJRIdcRm0K8G3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3yAf6KWkylJRIdcRm0K8G3',
#   'duration_ms': 206667,
#   'time_signature': 4},
#  {'danceability': 0.174,
#   'energy': 0.0444,
#   'key': 2,
#   'loudness': -15.948,
#   'mode': 0,
#   'speechiness': 0.0376,
#   'acousticness': 0.926,
#   'instrumentalness': 0.872,
#   'liveness': 0.0735,
#   'valence': 0.033,
#   'tempo': 70.971,
#   'type': 'audio_features',
#   'id': '4ZwbPLiBRlKA8jLFVoIPFi',
#   'uri': 'spotify:track:4ZwbPLiBRlKA8jLFVoIPFi',
#   'track_href': 'https://api.spotify.com/v1/tracks/4ZwbPLiBRlKA8jLFVoIPFi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ZwbPLiBRlKA8jLFVoIPFi',
#   'duration_ms': 438298,
#   'time_signature': 3},
#  {'danceability': 0.312,
#   'energy': 0.0609,
#   'key': 3,
#   'loudness': -14.198,
#   'mode': 1,
#   'speechiness': 0.0411,
#   'acousticness': 0.966,
#   'instrumentalness': 0.89,
#   'liveness': 0.18,
#   'valence': 0.172,
#   'tempo': 119.314,
#   'type': 'audio_features',
#   'id': '0tPOS7HpIeFmBb3UNTqTJ6',
#   'uri': 'spotify:track:0tPOS7HpIeFmBb3UNTqTJ6',
#   'track_href': 'https://api.spotify.com/v1/tracks/0tPOS7HpIeFmBb3UNTqTJ6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0tPOS7HpIeFmBb3UNTqTJ6',
#   'duration_ms': 314969,
#   'time_signature': 4},
#  {'danceability': 0.405,
#   'energy': 0.0741,
#   'key': 0,
#   'loudness': -15.053,
#   'mode': 0,
#   'speechiness': 0.035,
#   'acousticness': 0.944,
#   'instrumentalness': 0.851,
#   'liveness': 0.115,
#   'valence': 0.0468,
#   'tempo': 100.028,
#   'type': 'audio_features',
#   'id': '68cIWEReM7H9qG2ZYmkGMq',
#   'uri': 'spotify:track:68cIWEReM7H9qG2ZYmkGMq',
#   'track_href': 'https://api.spotify.com/v1/tracks/68cIWEReM7H9qG2ZYmkGMq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/68cIWEReM7H9qG2ZYmkGMq',
#   'duration_ms': 310490,
#   'time_signature': 4},
#  {'danceability': 0.197,
#   'energy': 0.13,
#   'key': 0,
#   'loudness': -14.769,
#   'mode': 0,
#   'speechiness': 0.0335,
#   'acousticness': 0.958,
#   'instrumentalness': 0.929,
#   'liveness': 0.0712,
#   'valence': 0.0356,
#   'tempo': 71.852,
#   'type': 'audio_features',
#   'id': '7fb5cLWytQFjpnnlULMgbb',
#   'uri': 'spotify:track:7fb5cLWytQFjpnnlULMgbb',
#   'track_href': 'https://api.spotify.com/v1/tracks/7fb5cLWytQFjpnnlULMgbb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7fb5cLWytQFjpnnlULMgbb',
#   'duration_ms': 546877,
#   'time_signature': 4},
#  {'danceability': 0.334,
#   'energy': 0.0701,
#   'key': 4,
#   'loudness': -12.954,
#   'mode': 1,
#   'speechiness': 0.0414,
#   'acousticness': 0.935,
#   'instrumentalness': 0.641,
#   'liveness': 0.0925,
#   'valence': 0.0656,
#   'tempo': 119.672,
#   'type': 'audio_features',
#   'id': '7Lk93HVP0rQkYVGoxsgh1T',
#   'uri': 'spotify:track:7Lk93HVP0rQkYVGoxsgh1T',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Lk93HVP0rQkYVGoxsgh1T',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Lk93HVP0rQkYVGoxsgh1T',
#   'duration_ms': 194891,
#   'time_signature': 5},
#  {'danceability': 0.416,
#   'energy': 0.225,
#   'key': 7,
#   'loudness': -16.362,
#   'mode': 1,
#   'speechiness': 0.0329,
#   'acousticness': 0.923,
#   'instrumentalness': 0.917,
#   'liveness': 0.111,
#   'valence': 0.0385,
#   'tempo': 138.105,
#   'type': 'audio_features',
#   'id': '5RqReNZMBlyi0bImwYhmbt',
#   'uri': 'spotify:track:5RqReNZMBlyi0bImwYhmbt',
#   'track_href': 'https://api.spotify.com/v1/tracks/5RqReNZMBlyi0bImwYhmbt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5RqReNZMBlyi0bImwYhmbt',
#   'duration_ms': 321854,
#   'time_signature': 4},
#  {'danceability': 0.413,
#   'energy': 0.067,
#   'key': 11,
#   'loudness': -11.683,
#   'mode': 0,
#   'speechiness': 0.0402,
#   'acousticness': 0.934,
#   'instrumentalness': 0.369,
#   'liveness': 0.142,
#   'valence': 0.293,
#   'tempo': 142.422,
#   'type': 'audio_features',
#   'id': '6ykgspUyiyUgliVtzjRrY2',
#   'uri': 'spotify:track:6ykgspUyiyUgliVtzjRrY2',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ykgspUyiyUgliVtzjRrY2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ykgspUyiyUgliVtzjRrY2',
#   'duration_ms': 214047,
#   'time_signature': 3},
#  {'danceability': 0.19,
#   'energy': 0.0946,
#   'key': 0,
#   'loudness': -15.139,
#   'mode': 0,
#   'speechiness': 0.0324,
#   'acousticness': 0.961,
#   'instrumentalness': 0.866,
#   'liveness': 0.106,
#   'valence': 0.0363,
#   'tempo': 76.471,
#   'type': 'audio_features',
#   'id': '6at2OT6ik9751T772Sn53B',
#   'uri': 'spotify:track:6at2OT6ik9751T772Sn53B',
#   'track_href': 'https://api.spotify.com/v1/tracks/6at2OT6ik9751T772Sn53B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6at2OT6ik9751T772Sn53B',
#   'duration_ms': 254974,
#   'time_signature': 3},
#  {'danceability': 0.221,
#   'energy': 0.118,
#   'key': 4,
#   'loudness': -14.747,
#   'mode': 0,
#   'speechiness': 0.0449,
#   'acousticness': 0.951,
#   'instrumentalness': 0.801,
#   'liveness': 0.114,
#   'valence': 0.0374,
#   'tempo': 81.74,
#   'type': 'audio_features',
#   'id': '381qo0VUzFJWO6PTRf3rsA',
#   'uri': 'spotify:track:381qo0VUzFJWO6PTRf3rsA',
#   'track_href': 'https://api.spotify.com/v1/tracks/381qo0VUzFJWO6PTRf3rsA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/381qo0VUzFJWO6PTRf3rsA',
#   'duration_ms': 194008,
#   'time_signature': 1},
#  {'danceability': 0.204,
#   'energy': 0.0827,
#   'key': 0,
#   'loudness': -18.021,
#   'mode': 0,
#   'speechiness': 0.043,
#   'acousticness': 0.927,
#   'instrumentalness': 0.894,
#   'liveness': 0.105,
#   'valence': 0.0349,
#   'tempo': 111.02,
#   'type': 'audio_features',
#   'id': '3XTIMboeTUHNRIZpfOd6Js',
#   'uri': 'spotify:track:3XTIMboeTUHNRIZpfOd6Js',
#   'track_href': 'https://api.spotify.com/v1/tracks/3XTIMboeTUHNRIZpfOd6Js',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3XTIMboeTUHNRIZpfOd6Js',
#   'duration_ms': 459455,
#   'time_signature': 4},
#  {'danceability': 0.0864,
#   'energy': 0.0662,
#   'key': 9,
#   'loudness': -14.721,
#   'mode': 1,
#   'speechiness': 0.042,
#   'acousticness': 0.886,
#   'instrumentalness': 0.919,
#   'liveness': 0.0852,
#   'valence': 0.0369,
#   'tempo': 70.173,
#   'type': 'audio_features',
#   'id': '3ZVLbEbxrLbxTqXG3pcTnh',
#   'uri': 'spotify:track:3ZVLbEbxrLbxTqXG3pcTnh',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZVLbEbxrLbxTqXG3pcTnh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZVLbEbxrLbxTqXG3pcTnh',
#   'duration_ms': 314862,
#   'time_signature': 3},
#  {'danceability': 0.284,
#   'energy': 0.579,
#   'key': 5,
#   'loudness': -6.692,
#   'mode': 1,
#   'speechiness': 0.037,
#   'acousticness': 0.565,
#   'instrumentalness': 0.673,
#   'liveness': 0.344,
#   'valence': 0.107,
#   'tempo': 94.892,
#   'type': 'audio_features',
#   'id': '4lIOFagrZ6UlIjEM0ZP6q8',
#   'uri': 'spotify:track:4lIOFagrZ6UlIjEM0ZP6q8',
#   'track_href': 'https://api.spotify.com/v1/tracks/4lIOFagrZ6UlIjEM0ZP6q8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4lIOFagrZ6UlIjEM0ZP6q8',
#   'duration_ms': 290279,
#   'time_signature': 3}]
